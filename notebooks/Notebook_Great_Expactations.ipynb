# %% [markdown]
# # Machine Learning Operations Project
# The aim of the project is to simulate the realworld process of deploying machine learning models, using the concepts that we have discussed during the classes. This notebook is focuses on the implementation of ``Great Expectations`` with a connected user interface (UI).

# %% [markdown]
# ## Metadata
#
# **UTC**:
# Timestamp UTC seconds
#
# **Temperature[C]**:
# Air Temperature
#
# **Humidity[%]**:
# Air Humidity
#
# **TVOC[ppb]**:
# Total Volatile Organic Compounds; measured in parts per billion
#
# **eCO2[ppm]**:
# CO2 equivalent concentration; calculated from different values like TVOC
#
# **Raw H2**:
# Raw molecular hydrogen; not compensated (Bias, temperature, etc.)
#
# **Raw Ethanol**:
# Raw ethanol gas
#
# **Pressure[hPa]**:
# Air Pressure
#
# **PM1.0**:
# Particulate matter size < 1.0 µm (PM1.0). 1.0 µm < 2.5 µm (PM2.5)
#
# **PM2.5**:
# Particulate matter size < 1.0 µm (PM1.0). 1.0 µm < 2.5 µm (PM2.5)
#
# **NC0.5**:
# Number concentration of particulate matter. This differs from PM because NC gives the actual number of particles in the air. The raw NC is also classified by the particle size: < 0.5 µm (NC0.5); 0.5 µm < 1.0 µm (NC1.0); 1.0 µm < 2.5 µm (NC2.5);
#
# **NC1.0**:
# Number concentration of particulate matter. This differs from PM because NC gives the actual number of particles in the air. The raw NC is also classified by the particle size: < 0.5 µm (NC0.5); 0.5 µm < 1.0 µm (NC1.0); 1.0 µm < 2.5 µm (NC2.5);
#
# **NC2.5**:
# Number concentration of particulate matter. This differs from PM because NC gives the actual number of particles in the air. The raw NC is also classified by the particle size: < 0.5 µm (NC0.5); 0.5 µm < 1.0 µm (NC1.0); 1.0 µm < 2.5 µm (NC2.5);
#
# **CNT**:
# Sample counter
#
# **Fire Alarm (Target)**:
# Ground truth is "1" if a fire is there

# %% [markdown]
# ## Imports

# %%
# Basic imports
import os
import json
import pandas as pd
import numpy as np
import seaborn as sns
from typing import Tuple
import matplotlib.pyplot as plt
# import great_expectations.jupyter_ux

# %%
dataframe = pd.read_csv('../data/01_raw/smoke_detection_1.csv', index_col=[0])

# %%
# def split_dataframe(dataframe: pd.DataFrame, output_filenames: list) -> None:
#     # Order dataframe by month
#     dataframe = dataframe.sort_values(by='UTC').reset_index(drop=True)

#     # Split dataframe into 3 equal-sized datasets
#     size = len(dataframe)
#     third = size // 3

#     # Split the dataframe
#     dataframe_1 = dataframe.iloc[:third]
#     dataframe_2 = dataframe.iloc[third:third*2]
#     dataframe_3 = dataframe.iloc[third*2:]

#     # Save each split dataframe as a CSV file
#     for df, filename in zip([dataframe_1, dataframe_2, dataframe_3], output_filenames):
#         df.to_csv(filename, index=False)

# # Apply function
# split_dataframe(dataframe, ['df_one.csv', 'df_two.csv', 'df_three.csv'])

# %% [markdown]
# # <span style="color: #FE6C1B;">Great Expectations</span>

# %% [markdown]
# ## Terminologies
#
# *Context*: A context in is the main object that manages the overall configuration and execution of the data expectations. It serves as a container for storing and organizing expectations, data sources, and validation results. The context allows to define, execute, and manage our data expectations.
#
# *Validator*: A validator is responsible for evaluating expectations on a given batch of data. Validators are used to validate data against a set of predefined expectations. They help to assess data quality, perform data validation, and monitor data pipelines.
#
# *Suite*: An Expectation Suite is a collection of expectations that define the desired properties and characteristics of our data. It serves as a set of rules against which your data can be validated. The suite contains a set of expectations that can be applied to one or more batches of data.
#
# *Batch*: A batch represents a subset of data that we want to evaluate against our expectations. It can be a collection of rows, a partitioned dataset, a file, a table, or any other logical grouping of data. Batches are used as inputs to validation processes and contain the data you want to validate.
#
# *Checkpoint*: A Checkpoint is a way to operationalize data validation using Expectation Suites. It allows you to define a pipeline-like flow for performing data validation on batches of data. It helps automate the validation process by defining the steps to be executed on data batches and tracking the results.

# %% [markdown]
# ## Installation
#
# - Open Anaconda Prompt Terminal
# - After satisfying ``!pip install great_expectations``, run ``great_expectations init`` and confirm with 'Y'
# - Verify the installation by running the version ``!great_expectations --version``
# - Our version used: version 0.16.13
#
#
# More information: https://docs.greatexpectations.io/docs/tutorials/quickstart/

# %%
# After setting up great_expectations init
for i in os.listdir('/Users/lukas/great_expectations'):
    print(i)
# Out:
# .DS_Store
# great_expectations.yml
# plugins
# checkpoints
# expectations
# profilers
# .gitignore
# great_expectations
# notebook
# data
# uncommitted

# %% [markdown]
# ## Getting started

# %%
# Set up
import great_expectations as gx
from great_expectations.checkpoint import SimpleCheckpoint

# Create data context
context = gx.get_context(
    context_root_dir='/Users/lukas/great_expectations'
)

# Connect to data
validator = context.sources.pandas_default.read_csv("df_one.csv")

# Extract column names
column_names = [f"{column_name}" for column_name in validator.columns()]
print(f"Columns: {', '.join(column_names)}.")
print(validator.head(n_rows=5, fetch_all=False))

# Create expectation suite
expectation_suite_name = "smoke_detection_suite"
suite = context.create_expectation_suite(expectation_suite_name=expectation_suite_name,overwrite_existing=True)
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Columns: UTC, Temperature[C], Humidity[%], TVOC[ppb], eCO2[ppm], Raw H2, Raw Ethanol, Pressure[hPa], PM1.0, PM2.5, NC0.5, NC1.0, NC2.5, CNT, Fire Alarm.
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#           UTC  Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]  Raw H2  \
# 0  1654712187           27.45        43.27         48        488   12844
# 1  1654712188           27.41        43.54         32        457   12857
# 2  1654712189           27.36        43.76         34        455   12857
# 3  1654712190           27.32        43.84         29        454   12858
# 4  1654712191           27.27        43.98         28        456   12860
#
#    Raw Ethanol  Pressure[hPa]  PM1.0  PM2.5  NC0.5  NC1.0  NC2.5  CNT  \
# 0        20723        937.586   2.04   2.12  14.05  2.191  0.049    0
# 1        20743        937.589   2.16   2.24  14.83  2.313  0.052    1
# 2        20747        937.604   2.19   2.28  15.07  2.350  0.053    2
# 3        20752        937.610   2.24   2.32  15.39  2.400  0.054    3
# 4        20751        937.601   2.26   2.35  15.58  2.429  0.055    4
#
#    Fire Alarm
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1

# %% [markdown]
# ## Expectations
# Now we use that data source for profiling, validation and documentation. More information regarding expectations, can be found here: https://legacy.docs.greatexpectations.io/en/latest/reference/glossary_of_expectations.html

# %%
# Use the Validator to create and run an Expectation
# Assert column count
validator.expect_table_column_count_to_equal(15)
# Out:
# Calculating Metrics:   0%|          | 0/3 [00:00<?, ?it/s]
# {
#   "success": true,
#   "meta": {},
#   "result": {
#     "observed_value": 15
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# Assert data types
validator.expect_column_values_to_be_of_type("UTC", "int64")
validator.expect_column_values_to_be_of_type("Temperature[C]", "float")
validator.expect_column_values_to_be_of_type("Humidity[%]", "float")
validator.expect_column_values_to_be_of_type("TVOC[ppb]", "int64")
validator.expect_column_values_to_be_of_type("eCO2[ppm]", "int64")
validator.expect_column_values_to_be_of_type("Raw H2", "int64")
validator.expect_column_values_to_be_of_type("Raw Ethanol", "int64")
validator.expect_column_values_to_be_of_type("Pressure[hPa]", "float")
validator.expect_column_values_to_be_of_type("PM1.0", "float")
validator.expect_column_values_to_be_of_type("PM2.5", "float")
validator.expect_column_values_to_be_of_type("NC0.5", "float")
validator.expect_column_values_to_be_of_type("NC1.0", "float")
validator.expect_column_values_to_be_of_type("NC2.5", "float")
validator.expect_column_values_to_be_of_type("CNT", "int64")
validator.expect_column_values_to_be_of_type("Fire Alarm", "int64")
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "success": true,
#   "meta": {},
#   "result": {
#     "observed_value": "int64"
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
 # Assert no missing values
for column_name in column_names:
    validator.expect_column_values_to_not_be_null(column_name)
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Assert target variable
validator.expect_column_values_to_be_in_set("Fire Alarm", [0, 1])
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "meta": {},
#   "result": {
#     "element_count": 10438,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# Assert value ranges to detect outliers
validator.expect_column_stdev_to_be_between("Temperature[C]", min_value=10, max_value=20)
validator.expect_column_stdev_to_be_between("Humidity[%]", min_value=5, max_value=15)
validator.expect_column_values_to_be_between("TVOC[ppb]", min_value=0, max_value=None)
validator.expect_column_values_to_be_between("eCO2[ppm]", min_value=0, max_value=None)
validator.expect_column_mean_to_be_between("Pressure[hPa]", min_value=930, max_value=940)
validator.expect_column_values_to_be_between("PM1.0", min_value=0, max_value=None)
validator.expect_column_values_to_be_between("PM2.5", min_value=0, max_value=None)
validator.expect_column_values_to_be_between("NC0.5", min_value=0, max_value=None)
validator.expect_column_values_to_be_between("NC1.0", min_value=0, max_value=None)
validator.expect_column_values_to_be_between("NC2.5", min_value=0, max_value=None)
# Out:
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "meta": {},
#   "result": {
#     "element_count": 10438,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ## Great Expectations UI

# %%
# Review and save our expectation suite
print(validator.get_expectation_suite(discard_failed_expectations=False))
validator.save_expectation_suite('data_expectations.json')

# Create checkpoint
checkpoint = SimpleCheckpoint(
    "smoke_detection_checkpoint",
    context,
    validator=validator,
)

# Run checkpoint to validate data 
checkpoint_result = checkpoint.run()

# View results
context.build_data_docs()
validation_result_identifier = checkpoint_result.list_validation_result_identifiers()[0]
context.open_data_docs(resource_identifier=validation_result_identifier)
# Out:
# {
#   "ge_cloud_id": null,
#   "expectation_suite_name": "default",
#   "data_asset_type": null,
#   "expectations": [
#     {
#       "expectation_type": "expect_table_column_count_to_equal",
#       "meta": {},
#       "kwargs": {
#         "value": 15
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "UTC",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "Temperature[C]",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "Humidity[%]",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "TVOC[ppb]",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "eCO2[ppm]",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "Raw H2",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "Raw Ethanol",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "Pressure[hPa]",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "PM1.0",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "PM2.5",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "NC0.5",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "NC1.0",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "NC2.5",
#         "type_": "float"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "CNT",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "meta": {},
#       "kwargs": {
#         "column": "Fire Alarm",
#         "type_": "int64"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "UTC"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "Temperature[C]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "Humidity[%]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "TVOC[ppb]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "eCO2[ppm]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "Raw H2"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "Raw Ethanol"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "Pressure[hPa]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "PM1.0"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "PM2.5"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "NC0.5"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "NC1.0"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "NC2.5"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "CNT"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_not_be_null",
#       "meta": {},
#       "kwargs": {
#         "column": "Fire Alarm"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_in_set",
#       "meta": {},
#       "kwargs": {
#         "column": "Fire Alarm",
#         "value_set": [
#           0,
#           1
#         ]
#       }
#     },
#     {
#       "expectation_type": "expect_column_stdev_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 10,
#         "max_value": 20,
#         "column": "Temperature[C]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_stdev_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 5,
#         "max_value": 15,
#         "column": "Humidity[%]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "TVOC[ppb]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "eCO2[ppm]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_mean_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 930,
#         "max_value": 940,
#         "column": "Pressure[hPa]"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "PM1.0"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "PM2.5"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "NC0.5"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "NC1.0"
#       }
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_between",
#       "meta": {},
#       "kwargs": {
#         "min_value": 0,
#         "max_value": null,
#         "column": "NC2.5"
#       }
#     }
#   ],
#   "meta": {
#     "great_expectations_version": "0.16.16"
#   }
# }
# Calculating Metrics:   0%|          | 0/122 [00:00<?, ?it/s]

# %%
checkpoint_result
# Out:
# {
#   "run_id": {
#     "run_time": "2023-06-25T16:03:43.511452+01:00",
#     "run_name": null
#   },
#   "run_results": {
#     "ValidationResultIdentifier::default/__none__/20230625T150343.511452Z/default_pandas_datasource-#ephemeral_pandas_asset": {
#       "validation_result": {
#         "evaluation_parameters": {},
#         "meta": {
#           "great_expectations_version": "0.16.16",
#           "expectation_suite_name": "default",
#           "run_id": {
#             "run_time": "2023-06-25T16:03:43.511452+01:00",
#             "run_name": null
#           },
#           "batch_spec": {
#             "reader_method": "read_csv",
#             "reader_options": {
#               "filepath_or_buffer": "df_one.csv"
#             }
#           },
#           "batch_markers": {
#             "ge_load_time": "20230625T150338.902462Z",
#             "pandas_data_fingerprint": "5932fac32525643cf2d3b3a1ccd3329b"
#           },
#           "active_batch_definition": {
#             "datasource_name": "default_pandas_datasource",
#             "data_connector_name": "fluent",
#             "data_asset_name": "#ephemeral_pandas_asset",
#             "batch_identifiers": {}
#           },
#           "validation_time": "20230625T150343.519660Z",
#           "checkpoint_name": "smoke_detection_checkpoint",
#           "validation_id": null,
#           "checkpoint_id": null
#         },
#         "results": [
#           {
#             "expectation_config": {
#               "expectation_type": "expect_table_column_count_to_equal",
#               "meta": {},
#               "kwargs": {
#                 "value": 15,
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": 15
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "UTC",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "UTC",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "Temperature[C]",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "Temperature[C]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_stdev_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 10,
#                 "max_value": 20,
#                 "column": "Temperature[C]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": 14.29434233179516
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "Humidity[%]",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "Humidity[%]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_stdev_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 5,
#                 "max_value": 15,
#                 "column": "Humidity[%]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": 11.739180362375658
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "TVOC[ppb]",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "TVOC[ppb]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "TVOC[ppb]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "eCO2[ppm]",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "eCO2[ppm]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "eCO2[ppm]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "Raw H2",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "Raw H2",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "Raw Ethanol",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "Raw Ethanol",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "Pressure[hPa]",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "Pressure[hPa]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_mean_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 930,
#                 "max_value": 940,
#                 "column": "Pressure[hPa]",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": 938.338861084499
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "PM1.0",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "PM1.0",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "PM1.0",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "PM2.5",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "PM2.5",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "PM2.5",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "NC0.5",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "NC0.5",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "NC0.5",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "NC1.0",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "NC1.0",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "NC1.0",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "NC2.5",
#                 "type_": "float",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "float64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "NC2.5",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_between",
#               "meta": {},
#               "kwargs": {
#                 "min_value": 0,
#                 "max_value": null,
#                 "column": "NC2.5",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "CNT",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "CNT",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_of_type",
#               "meta": {},
#               "kwargs": {
#                 "column": "Fire Alarm",
#                 "type_": "int64",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "observed_value": "int64"
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_not_be_null",
#               "meta": {},
#               "kwargs": {
#                 "column": "Fire Alarm",
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "expectation_config": {
#               "expectation_type": "expect_column_values_to_be_in_set",
#               "meta": {},
#               "kwargs": {
#                 "column": "Fire Alarm",
#                 "value_set": [
#                   0,
#                   1
#                 ],
#                 "batch_id": "default_pandas_datasource-#ephemeral_pandas_asset"
#               }
#             },
#             "success": true,
#             "meta": {},
#             "result": {
#               "element_count": 10438,
#               "unexpected_count": 0,
#               "unexpected_percent": 0.0,
#               "partial_unexpected_list": [],
#               "missing_count": 0,
#               "missing_percent": 0.0,
#               "unexpected_percent_total": 0.0,
#               "unexpected_percent_nonmissing": 0.0,
#               "partial_unexpected_index_list": [],
#               "partial_unexpected_counts": []
#             },
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           }
#         ],
#         "statistics": {
#           "evaluated_expectations": 42,
#           "successful_expectations": 42,
#           "unsuccessful_expectations": 0,
#           "success_percent": 100.0
#         },
#         "success": true
#       },
#       "actions_results": {
#         "store_validation_result": {
#           "class": "StoreValidationResultAction"
#         },
#         "store_evaluation_params": {
#           "class": "StoreEvaluationParametersAction"
#         },
#         "update_data_docs": {
#           "local_site": "file:///Users/lukas/great_expectations/uncommitted/data_docs/local_site/validations/default/__none__/20230625T150343.511452Z/default_pandas_datasource-%23ephemeral_pandas_asset.html",
#           "class": "UpdateDataDocsAction"
#         }
#       }
#     }
#   },
#   "checkpoint_config": {
#     "config_version": 1.0,
#     "runtime_configuration": {},
#     "notify_with": null,
#     "run_name_template": null,
#     "name": "smoke_detection_checkpoint",
#     "site_names": null,
#     "template_name": null,
#     "slack_webhook": null,
#     "validations": [],
#     "class_name": "SimpleCheckpoint",
#     "ge_cloud_id": null,
#     "expectation_suite_name": "default",
#     "default_validation_id": null,
#     "notify_on": null,
#     "batch_request": {},
#     "expectation_suite_ge_cloud_id": null,
#     "action_list": [
#       {
#         "name": "store_validation_result",
#         "action": {
#           "class_name": "StoreValidationResultAction"
#         }
#       },
#       {
#         "name": "store_evaluation_params",
#         "action": {
#           "class_name": "StoreEvaluationParametersAction"
#         }
#       },
#       {
#         "name": "update_data_docs",
#         "action": {
#           "class_name": "UpdateDataDocsAction"
#         }
#       }
#     ],
#     "evaluation_parameters": {},
#     "module_name": "great_expectations.checkpoint",
#     "profilers": []
#   },
#   "success": true
# }

# %% [markdown]
# ## References
# - https://medium.com/@mostsignificant/python-data-validation-made-easy-with-the-great-expectations-package-8d1be266fd3f
# - https://towardsdatascience.com/great-expectations-automated-testing-for-data-science-and-engineering-teams-1e7c78f1d2d5
# - https://towardsdatascience.com/a-great-python-library-great-expectations-6ac6d6fe822e
# - https://github.com/datarootsio/tutorial-great-expectations/blob/main/tutorial_great_expectations.ipynb
